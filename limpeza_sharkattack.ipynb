# %%
import pandas as pd

# %%
shark_attack = pd.read_csv(r'/Users/FAB/Documents/GitHub/Limpeza-de-Dados-Shark/attacks.csv', encoding = 'latin-1')

# %%
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#shark_attack.columns = ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#       'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#       'Species ', 'Investigator or Source']

# %%
shark_attack = shark_attack.drop(['pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
       'Unnamed: 23'], axis = 1)

# %%
shark_attack
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
shark_attack.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# dtype: object

# %%
brazil_mask = shark_attack ['Country'] == 'BRAZIL'

# %%
shark_attack = shark_attack.drop('Name', axis = 1)

# %%
#shark_attack [brazil_mask]

# %%
#pernambuco_mask = shark_attack['Area'] == 'Pernambuco'
#shark_attack[pernambuco_mask]

# %%
pd.set_option('display.max_rows', 20)

# %%
#shark_attack[pernambuco_mask]

# %%
shark_attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source'],
#       dtype='object')

# %%
shark_attack.columns = ['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
       'Activity', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species',
       'Investigator or Source']

# %%
#mascara_tigre = shark_attack['Species'].str.lower().str.contains('tiger')

# %%
shark_attack.shape
# Out:
# (25723, 15)

# %%
shark_attack.dropna(axis=0, how='any', subset='Species', inplace=True)
#remoçao de linhas sem identificaçao da espécie de tubarão

# %%
mascara_tiger = shark_attack['Species'].str.lower().str.contains('tiger')

# %%
shark_attack[mascara_tiger]
# Out:
#        Case Number                  Date    Year        Type     Country  \
# 4       2018.06.04           04-Jun-2018  2018.0    Provoked      MEXICO
# 6     2018.06.03.a           03-Jun-2018  2018.0  Unprovoked      BRAZIL
# 18    2018.04.28.b           28-Apr-2018  2018.0  Unprovoked  COSTA RICA
# 23      2018.04.23           23-Apr-2018  2018.0  Unprovoked    MALDIVES
# 30      2018.04.14           14-Apr-2018  2018.0  Unprovoked     BAHAMAS
# ...            ...                   ...     ...         ...         ...
# 6139  1785.09.26.R  Reported 26-Sep-1785  1785.0  Unprovoked     ENGLAND
# 6214       ND.0104                 1950s     0.0  Unprovoked   AUSTRALIA
# 6215       ND.0102  No date, Before 1963     0.0  Unprovoked     BAHREIN
# 6240       ND.0066           Before 1961     0.0  Unprovoked  SEYCHELLES
# 6276       ND.0026           Early 1930s     0.0  Unprovoked      BELIZE
#
#                    Area               Location  \
# ...

# %%
shark_attack.dropna(axis=0, how='any', subset='Year', inplace=True)
#removendo as linhas com valores nulos na coluna 'anos'

# %%
# Transformando a coluna 'Year' de float64 para int64 com o método 'astype'
shark_attack = shark_attack.fillna(0)
shark_attack.Year.astype(int)
shark_attack['Year'] = shark_attack['Year'].astype('int64')

# %%
shark_attack['Year'].unique()
#mostar os valores diferentes para ano
# Out:
# array([2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008,
#        2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997,
#        1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1969, 1988, 1987,
#        1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976,
#        1975, 1974, 1973, 1972, 1971, 1970, 1968, 1967, 1966, 1965, 1964,
#        1963, 1962, 1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953,
#        1952, 1951, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1943, 1942,
#        1941, 1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931,
#        1930, 1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921, 1920,
#        1919, 1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911, 1910, 1909,
#        1908, 1907, 1906, 1905, 1904, 1903, 1902, 1901, 1900, 1899, 1898,
#        1897, 1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889, 1888, 1887,
#        1886, 1885, 1884, 1883, 1882, 1881, 1880, 1879, 1878, 1877, 1876,
# ...

# %%
shark_attack = shark_attack[shark_attack['Year'] >= 1543]

# %%
tiger_shark_attack = shark_attack[mascara_tiger]
# Out:
# /var/folders/b0/_s54160d52d37v51bszg4cmh0000gp/T/ipykernel_41129/513265003.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tiger_shark_attack = shark_attack[mascara_tiger]

# %%
#tiger_shark_attack
#novo dataframe já filtrado apenas os tubarões tigre

# %%
shark_attack['Country'].value_counts()
# Out:
# USA                   1316
# AUSTRALIA              785
# SOUTH AFRICA           420
# NEW ZEALAND             78
# BAHAMAS                 75
#                       ...
# HONDURAS                 1
# MID ATLANTIC OCEAN       1
# PERSIAN GULF             1
# NORTH SEA                1
# GUINEA                   1
# Name: Country, Length: 145, dtype: int64

# %%
tiger_shark_attack['Country'].value_counts()
# Out:
# USA              122
# AUSTRALIA         55
# BRAZIL            12
# SOUTH AFRICA      12
# NEW CALEDONIA      9
#                 ...
# JAMAICA            1
# NEW ZEALAND        1
# Fiji               1
# CARIBBEAN SEA      1
# ENGLAND            1
# Name: Country, Length: 37, dtype: int64

# %%
shark_brazil = shark_attack[brazil_mask]
# Out:
# /var/folders/b0/_s54160d52d37v51bszg4cmh0000gp/T/ipykernel_41129/1021720358.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   shark_brazil = shark_attack[brazil_mask]

# %%
fatal_mask = shark_attack['Fatal (Y/N)'] == 'Y'

# %%
tiger_shark_attack['Country'].value_counts()
# Out:
# USA              122
# AUSTRALIA         55
# BRAZIL            12
# SOUTH AFRICA      12
# NEW CALEDONIA      9
#                 ...
# JAMAICA            1
# NEW ZEALAND        1
# Fiji               1
# CARIBBEAN SEA      1
# ENGLAND            1
# Name: Country, Length: 37, dtype: int64

# %%
usa_mask = tiger_shark_attack ['Country'] == 'USA'

# %%
tiger_usa = tiger_shark_attack[usa_mask]

# %%
tiger_usa['Area'].value_counts()
# Out:
# Hawaii            84
# Florida           15
# North Carolina     8
# New Jersey         2
# Louisiana          2
# South Carolina     2
# Alabama            1
# Delaware           1
# Guam               1
# New Mexico         1
# Virginia           1
# Texas              1
# Puerto Rico        1
# California         1
# Mississippi        1
# Name: Area, dtype: int64

# %%
shark_brazil ['Area'].value_counts()
# Out:
# Pernambuco              23
# Rio de Janeiro           5
# 0                        2
# Alagoas                  1
# Boi Island, Victoria     1
# Fernando de Noronha      1
# Santa Catarina State     1
# Balneário Camboriú       1
# Rio Grande Do Sul        1
# Maranhão                 1
# Bahia                    1
# Name: Area, dtype: int64

# %%
shark_brazil.shape
# Out:
# (38, 15)

# %%
tiger_usa ['Area'] == 'Guam'
# Out:
# 35      False
# 53      False
# 74      False
# 112     False
# 140     False
#         ...
# 4968    False
# 5017    False
# 5041    False
# 5836    False
# 6008    False
# Name: Area, Length: 122, dtype: bool
